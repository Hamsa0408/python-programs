# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamsa0408/python-programs/blob/main/sampleprograms1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = int(input())

for _ in range(t):
    n, b = map(int, input().split())

    max_area = 0

    for _ in range(n):
        w, h, p = map(int, input().split())

        if p <= b:
            area = w * h
            if area > max_area:
                max_area = area

    if max_area == 0:
        print("no tablet")
    else:
        print(max_area)

# %%
import math

t = int(input())

for _ in range(t):
    B, LS = map(int, input().split())

    mn = math.sqrt(LS * LS - B * B)
    mx = math.sqrt(LS * LS + B * B)

    print(mn, mx)

# %%
n=list(map(int,input().split()))
l = float('-inf')
sl = float('-inf')
for i in n:
    if i > l:
        sl=l
        l=i
    elif i > sl and i != l:
        sl = n

if sl == float('-inf'):
    print("No second largest element found")
else:
    print("Second largest:", sl)
# Out:
# 3 5 7 2 9
# Second largest: 7

# %%
s=input()
for ch in s:
  if s.count(ch)==1:
    print(ch)
    break
# Out:
# swiss
# w

# %%
n=list(map(int,input().split()))
k=int(input())
k = k % len(n)
result = n[-k:] + n[:-k]
print(result)
# Out:
# 3 5 7 2 9
# 1
# [9, 3, 5, 7, 2]

# %%
l=list(map(int,input().split()))
l1=[]
l2=[]
for i in l:
  if i%2 == 0:
    l1.append(i)
  else:
    l2.append(i)
result= l1+l2
print(result)
# Out:
# 4 3 1 8 6
# [4, 8, 6, 3, 1]

# %%
for num in range(1, 100):
    temp = num
    s = 0
    p = 1

    while temp > 0:
        digit = temp % 10
        s += digit
        p *= digit
        temp //= 10

    if s == p:
        print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 22

# %%
arr = [2, 7, 11, 15, 3, 6]
target = 9

for i in range(len(arr)):
    for j in range(i + 1, len(arr)):
        if arr[i] + arr[j] == target:
            print((arr[i], arr[j]))
# Out:
# (2, 7)
# (3, 6)

# %%
l=eval(input())
s=0
for rows in l:
  for i in rows:
    s=s+i
print(s)
# Out:
# [[1,2],[3,4],[5,6]]
# 21

# %%
n=input()
v="aeiou"
count=0c
for i in n:
  if i not in v:
    count+=1
    print(i,end=" ")
# Out:
# hamsa
# h m s

# %%
def total(lst):
          s=0
          for i in lst:
            if isinstance(i,list):
              s+=total(i)
            else:
              s+=i
          return s
print(total([1,[2,3],[4,[5,6]]]))
# Out:
# 21
